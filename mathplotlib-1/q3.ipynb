# %%
import matplotlib.pyplot as plt

years = [1990,2000,2010,2020,2030,2040]
gdp = [300.2,543.3,1075.9,2862.5,5979.6,10289.7]
plt.plot(years,gdp,marker='o',linestyle= 'solid', color = "red")
plt.title("Nominal gdp of india")
plt.ylabel("Billion of rupees")
plt.xlabel("year")

plt.grid()

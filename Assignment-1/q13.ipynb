# %%
#QUESTION13
import matplotlib.pyplot as plt
mentions = [500, 505]
years = [2017, 2018]
plt.bar(years, mentions, 0.2)
plt.xlabel('Year')
plt.ylabel('Number of Mentions')
plt.title('Mentions per Year')
plt.show()
